# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR

# %%
# Best Dataset combination that produces is protein embeddings + yeastnet + gen expressions
yeast_emb_best = pd.read_csv('../Data/yeast_emb_embeddings_yeastnet_genex.csv', sep = ',', index_col = 0)
yeast_emb_best
# Out:
#         gene_id  gc_5_prime  gc_3_prime    gc_cds       AAA       AAC  \
# 0       YAL002W    0.365902    0.310000  0.372057  0.043956  0.019623
# 1       YAL003W    0.372881    0.253333  0.448220  0.009709  0.024272
# 2       YAL004W    0.417747    0.346667  0.451163  0.023256  0.023256
# 3       YAL008W    0.381854    0.296667  0.388889  0.045455  0.020202
# 4       YAL009W    0.368893    0.323333  0.414414  0.042471  0.011583
# ...         ...         ...         ...       ...       ...       ...
# 6574    YPR195C    0.334995    0.393333  0.467890  0.027523  0.000000
# 6575    YPR197C    0.376869    0.276667  0.374332  0.058824  0.021390
# 6576    YPR199C    0.329013    0.283333  0.391156  0.030612  0.020408
# 6577    YPR200C    0.366899    0.313333  0.376923  0.038462  0.015385
# 6578  YPR204C-A    0.402189    0.426667  0.454167  0.031250  0.018750
#
#            AAG       AAT       ACA       ACC  ...  \
# 0     0.018053  0.039246  0.013344  0.007849  ...
# 1     0.077670  0.004854  0.000000  0.019417  ...
# 2     0.000000  0.046512  0.004651  0.074419  ...
# 3     0.040404  0.050505  0.015152  0.005051  ...
# 4     0.023166  0.027027  0.011583  0.007722  ...
# ...        ...       ...       ...       ...  ...
# 6574  0.000000  0.027523  0.045872  0.009174  ...
# 6575  0.021390  0.016043  0.042781  0.005348  ...
# 6576  0.047619  0.047619  0.027211  0.003401  ...
# 6577  0.038462  0.023077  0.030769  0.015385  ...
# 6578  0.000000  0.012500  0.000000  0.006250  ...
#
#       data_Turco_expression_11808  data_Turco_expression_16247  \
# 0                       -1.454995                     0.120081
# 1                        0.187259                    -0.020342
# 2                        0.187259                    -0.020342
# 3                        0.200656                     0.120081
# 4                        0.203895                     0.120081
# ...                           ...                          ...
# 6574                     0.187259                    -0.020342
# 6575                     0.187259                    -0.020342
# 6576                    -0.006454                     0.120081
# 6577                     0.291845                     0.120081
# 6578                     0.187259                    -0.020342
#
#       data_Turco_expression_16248  data_Turco_expression_16249  \
# 0                        0.120937                     0.127851
# 1                        0.049383                    -0.085744
# 2                        0.049383                    -0.085744
# 3                        0.120937                     0.127851
# 4                        0.120937                    -4.034924
# ...                           ...                          ...
# 6574                     0.049383                    -0.085744
# 6575                     0.049383                    -0.085744
# 6576                     0.120937                     0.127851
# 6577                     0.120937                     0.127851
# 6578                     0.049383                    -0.085744
#
#       data_Turco_expression_16250  data_Turco_expression_16683  \
# 0                        0.128291                    -1.802252
# 1                       -0.124338                     0.035694
# 2                       -0.124338                     0.035694
# 3                        0.128291                     1.086489
# 4                        0.128291                     0.035502
# ...                           ...                          ...
# 6574                    -0.124338                     0.035694
# 6575                    -0.124338                     0.035694
# 6576                     0.128291                     1.170261
# 6577                     0.128291                     0.625506
# 6578                    -0.124338                     0.035694
#
#       data_Turco_expression_16684  data_Turco_expression_16685  \
# 0                       -1.220942                    -0.876121
# 1                        0.011140                     0.071771
# 2                        0.011140                     0.071771
# 3                        1.085078                     2.182672
# 4                        0.011022                     0.071563
# ...                           ...                          ...
# 6574                     0.011140                     0.071771
# 6575                     0.011140                     0.071771
# 6576                     0.623874                     0.551316
# 6577                     0.162670                     0.755235
# 6578                     0.011140                     0.071771
#
#       data_Turco_expression_21888  data_Turco_expression_21932
# 0                        0.854368                     1.492454
# 1                       -0.280784                     0.324166
# 2                       -0.280784                     0.324166
# 3                        0.616041                     1.037160
# 4                        0.298273                    -0.242586
# ...                           ...                          ...
# 6574                    -0.280784                     0.324166
# 6575                    -0.280784                     0.324166
# 6576                    -0.699168                    -0.390249
# 6577                    -1.114033                    -0.734796
# 6578                    -0.280784                     0.324166
#
# [6579 rows x 3024 columns]

# %%
# Check what is the percentage of the variance explained by compressed data compared to the full data 
N=128
pca = PCA(n_components=N)
pca.fit_transform(yeast_emb_best.iloc[:,1:])
ev = pca.explained_variance_ratio_.cumsum()
print(ev[-1])
plt.plot(range(0, N), ev)
# Out:
# 0.898449504615302

# %% [markdown]
# we retain around 90 % variance of the data

# %%
dims = 128
emb_best_pca = pd.DataFrame(PCA(n_components=dims).fit_transform(yeast_emb_best.iloc[:,1:]), index=yeast_emb_best.gene_id).reset_index()
emb_best_pca
# Out:
#         gene_id          0         1         2         3         4         5  \
# 0       YAL002W   1.089317 -3.011852  3.407517 -1.659293  0.086628 -0.591660
# 1       YAL003W   8.899154  3.204977 -6.893635 -6.380903 -1.007415  2.557472
# 2       YAL004W  -8.718575  4.936183  0.577745  1.291669  1.875184  3.353667
# 3       YAL008W   1.019033 -3.641889  4.323164 -5.738738 -2.624162 -0.870438
# 4       YAL009W   0.203211 -3.413058 -0.606505  0.741641 -4.085337  1.732034
# ...         ...        ...       ...       ...       ...       ...       ...
# 6574    YPR195C -12.833093  3.235372 -0.231510 -0.526165 -1.430143 -1.596875
# 6575    YPR197C -10.538519  8.001325  0.811370  2.577134  1.460791  5.534684
# 6576    YPR199C  -4.447035 -3.500898  1.487133 -0.135930  2.250918 -1.010256
# 6577    YPR200C   4.576115 -0.265081  2.466689 -1.803889 -0.699313 -3.362161
# 6578  YPR204C-A -14.561725  5.340554  0.464374  0.752096 -1.595566 -0.411570
#
#              6         7         8  ...       118       119       120  \
# 0     0.638391  0.288943 -2.140733  ... -0.350994  0.111836 -0.143796
# 1     1.371918  0.612207 -1.071300  ... -0.186386 -0.050768 -0.063283
# 2    -2.011013 -1.438096  0.111260  ...  0.917754  1.652527 -0.785038
# 3    -0.721395 -0.548745 -0.741677  ... -0.200887 -0.051053 -0.268214
# 4     2.617916 -1.501055 -0.651774  ...  0.016160 -0.324576  0.507385
# ...        ...       ...       ...  ...       ...       ...       ...
# 6574  1.093374  2.160359  0.502568  ...  0.096305  0.785914 -0.837016
# 6575 -3.539705 -4.089107 -0.134690  ...  0.170420  0.935918 -1.420475
# 6576  0.807654 -0.606445  0.611886  ... -0.338873 -0.459355  0.249487
# 6577 -2.044214  0.124364 -1.425217  ...  0.186582  0.346928  0.456462
# 6578  0.440347  0.603593 -0.591796  ...  0.847657  0.062053 -0.486778
#
#            121       122       123       124       125       126       127
# 0    -0.361526  0.771316  0.601057  0.542280 -0.116888 -0.242311 -0.383038
# 1     0.357533  0.588663 -0.309631 -0.032160  0.720927  0.507733 -0.019483
# 2     0.595996  0.659740 -0.460062  0.435492  0.848017  0.352326 -0.361779
# 3    -0.033937  0.316228  0.606535 -0.156796 -0.213998  0.283601  0.162691
# 4    -0.110544  0.028119  0.202751  0.047918 -0.123554  0.140686 -0.362256
# ...        ...       ...       ...       ...       ...       ...       ...
# 6574  0.240917  0.596410 -0.243880  0.321894  0.004942  0.337532 -0.248818
# 6575  0.945752 -0.393091  0.324048  0.539988 -0.146394  0.088511 -1.017859
# 6576  0.437150  0.081347 -0.378748  0.329968 -0.179441  0.103712  0.279370
# 6577 -0.096411  0.200305 -0.657006  0.512239 -0.075480  0.245670 -0.306475
# 6578  0.103751 -0.349878  0.541480  0.510628  0.877250 -0.087769 -0.461309
#
# [6579 rows x 129 columns]

# %% [markdown]
# # Simple evaluation on single mutant fitness data

# %%
# Read in single mutant fitness data from Constanzo et al. 2016
smf_filter = pd.read_csv('../Data/smf.csv', index_col = 0)

# %%
smf_filter.smf_30.hist(bins=100)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
# How predictive are gene embeddings with PCA + Linear Regression

A = smf_filter.merge(emb_best_pca, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

lm = LinearRegression().fit(X_train, y_train)
y_pred = lm.predict(X_test)

print('R2: ', lm.score(X_test, y_test))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))


plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("PCA + Linear Regression Predictions")
plt.show()
# Out:
# R2:  0.3052936456575991
# RMSE: 0.1521432751683412

# %%
# Comparison to only sequence features 
seq_feats = pd.read_csv('../Data/seq_feats.csv', sep = ',', index_col = 0)
A = smf_filter.merge(seq_feats, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=43)

lm = LinearRegression().fit(X_train, y_train)
y_pred = lm.predict(X_test)

print('R2: ', lm.score(X_test, y_test))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))


plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("Predictions Only Based on Sequence Features")
plt.show()
# Out:
# R2:  0.06702105271237235
# RMSE: 0.17250448804739613

# %%
# use Lasso Regression (L1 Regularization) instead of PCA
A = smf_filter.merge(yeast_emb_best, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=44)

lasso = Lasso(alpha=0.0004)
lasso.fit(X_train, y_train)
y_pred = lasso.predict(X_test)


print('R2: ', lasso.score(X_test, y_test))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("Lasso Regression Predictions")
plt.show()
# Out:
# R2:  0.29313792981754405
# RMSE: 0.15300554701125835

# %%
# use Ridge Regression (L2 Regularization) instead of PCA
A = smf_filter.merge(yeast_emb_best, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=45)

ridge = Ridge(alpha=200.0)
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)

print('R2: ', ridge.score(X_test, y_test))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("Ridge Regression Predictions")
plt.show()
# Out:
# R2:  0.31955569297158515
# RMSE: 0.15445292918062614

# %%
# use Random Forests instead of Linear Regression
A = smf_filter.merge(yeast_emb_best, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=46)

# Train a Random Forest model
rf = RandomForestRegressor(n_estimators=20, random_state=42)
rf.fit(X_train, y_train)
y_pred = rf.predict(X_test)

print("R2:", r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("Random Forest Predictions")
plt.show()
# Out:
# R2: 0.48637048558856755
# RMSE: 0.133422635052736

# %%
# use Support Vectors instead of Linear Regression
A = smf_filter.merge(yeast_emb_best, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=47)

# Train an SVR model
svr = SVR(kernel='rbf', C=2.0, epsilon=0.1)
svr.fit(X_train, y_train)
y_pred = svr.predict(X_test)

print('R2:', r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("SVR Predictions")
plt.show()
# Out:
# R2: 0.301948298545336
# RMSE: 0.14836189563597993

# %%
# use Gradient Boosting Regression instead of Linear Regression
A = smf_filter.merge(yeast_emb_best, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=48)

gb = GradientBoostingRegressor(n_estimators=20, learning_rate=0.2, max_depth=3, random_state=48)
gb.fit(X_train, y_train)

y_pred = gb.predict(X_test)
print('R2:', r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("Gradient Boosting Predictions")
plt.show()
# Out:
# R2: 0.46843533267148496
# RMSE: 0.13746720351529523

# %%
# Use Basic Neural Network
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Adam

A = smf_filter.merge(yeast_emb_best, on='gene_id', how='inner').dropna()
X = A.iloc[:, 5:]
y = A['smf_30']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=49)

model = Sequential([
    Input(shape=(X_train.shape[1],)),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse', metrics=['mse'])

model.fit(X_train, y_train, validation_split=0.2, epochs=50, batch_size=32, verbose=1)

loss, mae = model.evaluate(X_test, y_test)
y_pred = model.predict(X_test)
print('R2:', r2_score(y_test, y_pred))
print("RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))

plt.scatter(y_pred, y_test, alpha=0.5)
plt.xlabel("y-pred")
plt.ylabel("y-true")
plt.title("Neural Network Predictions")
plt.show()
# Out:
# Epoch 1/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2167 - mse: 0.2167 - val_loss: 0.0259 - val_mse: 0.0259
# Epoch 2/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0221 - mse: 0.0221 - val_loss: 0.0290 - val_mse: 0.0290
# Epoch 3/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0222 - mse: 0.0222 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 4/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0213 - mse: 0.0213 - val_loss: 0.0253 - val_mse: 0.0253
# Epoch 5/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0256 - val_mse: 0.0256
# Epoch 6/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0193 - mse: 0.0193 - val_loss: 0.0260 - val_mse: 0.0260
# Epoch 7/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 8/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0275 - val_mse: 0.0275
# Epoch 9/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0247 - val_mse: 0.0247
# Epoch 10/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0140 - mse: 0.0140 - val_loss: 0.0266 - val_mse: 0.0266
# Epoch 11/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0267 - val_mse: 0.0267
# Epoch 12/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0277 - val_mse: 0.0277
# Epoch 13/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0270 - val_mse: 0.0270
# Epoch 14/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0293 - val_mse: 0.0293
# Epoch 15/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 16/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 17/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0305 - val_mse: 0.0305
# Epoch 18/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0069 - mse: 0.0069 - val_loss: 0.0284 - val_mse: 0.0284
# Epoch 19/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0282 - val_mse: 0.0282
# Epoch 20/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0059 - mse: 0.0059 - val_loss: 0.0272 - val_mse: 0.0272
# Epoch 21/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0308 - val_mse: 0.0308
# Epoch 22/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0296 - val_mse: 0.0296
# Epoch 23/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0299 - val_mse: 0.0299
# Epoch 24/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0294 - val_mse: 0.0294
# Epoch 25/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0320 - val_mse: 0.0320
# Epoch 26/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0038 - mse: 0.0038 - val_loss: 0.0302 - val_mse: 0.0302
# Epoch 27/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0302 - val_mse: 0.0302
# Epoch 28/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0333 - val_mse: 0.0333
# Epoch 29/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0327 - val_mse: 0.0327
# Epoch 30/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0301 - val_mse: 0.0301
# Epoch 31/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0343 - val_mse: 0.0343
# Epoch 32/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0298 - val_mse: 0.0298
# Epoch 33/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0311 - val_mse: 0.0311
# Epoch 34/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0292 - val_mse: 0.0292
# Epoch 35/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0289 - val_mse: 0.0289
# Epoch 36/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0315 - val_mse: 0.0315
# Epoch 37/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0323 - val_mse: 0.0323
# Epoch 38/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 39/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0299 - val_mse: 0.0299
# Epoch 40/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0297 - val_mse: 0.0297
# Epoch 41/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0299 - val_mse: 0.0299
# Epoch 42/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0311 - val_mse: 0.0311
# Epoch 43/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0315 - val_mse: 0.0315
# Epoch 44/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0314 - val_mse: 0.0314
# Epoch 45/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 46/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0301 - val_mse: 0.0301
# Epoch 47/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0338 - val_mse: 0.0338
# Epoch 48/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0307 - val_mse: 0.0307
# Epoch 49/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0311 - val_mse: 0.0311
# Epoch 50/50
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0304 - val_mse: 0.0304
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 534us/step - loss: 0.0308 - mse: 0.0308
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 640us/step
# R2: 0.11769855249960803
# RMSE: 0.17296984872355486
